# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\puspa\OneDrive\Desktop\hotel_bookings.csv')

# %%
df.head()
# Out:
#           hotel  cancellation_status  lead_time  arrival_date_year  \
# 0  Resort Hotel                    0        342               2015
# 1  Resort Hotel                    0        737               2015
# 2  Resort Hotel                    0          7               2015
# 3  Resort Hotel                    0         13               2015
# 4  Resort Hotel                    0         14               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  company  \
# ...

# %%
df.shape
# Out:
# (65463, 34)

# %%
df.columns
# Out:
# Index(['hotel', 'cancellation_status', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type',
#        'average_daily_rate', 'required_car_parking_spaces',
#        'total_of_special_requests', 'reservation_status',
#        'reservation_status_date', 'Total Guests', 'Total Nights'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65463 entries, 0 to 65462
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           65463 non-null  object
#  1   cancellation_status             65463 non-null  int64
#  2   lead_time                       65463 non-null  int64
#  3   arrival_date_year               65463 non-null  int64
#  4   arrival_date_month              65463 non-null  object
#  5   arrival_date_week_number        65463 non-null  int64
#  6   arrival_date_day_of_month       65463 non-null  int64
#  7   stays_in_weekend_nights         65463 non-null  int64
#  8   stays_in_week_nights            65463 non-null  int64
#  9   adults                          65463 non-null  int64
#  10  children                        65463 non-null  int64
#  11  babies                          65463 non-null  int64
# ...

# %%
df.describe()
# Out:
#        cancellation_status     lead_time  arrival_date_year  \
# count         65463.000000  65463.000000       65463.000000
# mean              0.366360     79.846830        2016.081832
# std               0.481813     87.097199           0.693513
# min               0.000000      0.000000        2015.000000
# 25%               0.000000     11.000000        2016.000000
# 50%               0.000000     48.000000        2016.000000
# 75%               1.000000    124.000000        2017.000000
# max               1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              65463.000000               65463.000000
# mean                  26.545132                  15.771948
# std                   13.675474                   8.835450
# min                    1.000000                   1.000000
# 25%                   15.000000                   8.000000
# 50%                   27.000000                  16.000000
# ...

# %%
df.isnull().sum()
# Out:
# hotel                               0
# cancellation_status                 0
# lead_time                           0
# arrival_date_year                   0
# arrival_date_month                  0
# arrival_date_week_number            0
# arrival_date_day_of_month           0
# stays_in_weekend_nights             0
# stays_in_week_nights                0
# adults                              0
# children                            0
# babies                              0
# meal                                0
# country                           446
# market_segment                      0
# distribution_channel                0
# is_repeated_guest                   0
# previous_cancellations              0
# previous_bookings_not_canceled      0
# reserved_room_type                  0
# assigned_room_type                  0
# booking_changes                     0
# deposit_type                        0
# agent                               0
# company                             0
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65463 entries, 0 to 65462
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           65463 non-null  object
#  1   cancellation_status             65463 non-null  int64
#  2   lead_time                       65463 non-null  int64
#  3   arrival_date_year               65463 non-null  int64
#  4   arrival_date_month              65463 non-null  object
#  5   arrival_date_week_number        65463 non-null  int64
#  6   arrival_date_day_of_month       65463 non-null  int64
#  7   stays_in_weekend_nights         65463 non-null  int64
#  8   stays_in_week_nights            65463 non-null  int64
#  9   adults                          65463 non-null  int64
#  10  children                        65463 non-null  int64
#  11  babies                          65463 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# hotel                             0
# cancellation_status               0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
df['total_stay'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65463 entries, 0 to 65462
# Data columns (total 35 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           65463 non-null  object
#  1   cancellation_status             65463 non-null  int64
#  2   lead_time                       65463 non-null  int64
#  3   arrival_date_year               65463 non-null  int64
#  4   arrival_date_month              65463 non-null  object
#  5   arrival_date_week_number        65463 non-null  int64
#  6   arrival_date_day_of_month       65463 non-null  int64
#  7   stays_in_weekend_nights         65463 non-null  int64
#  8   stays_in_week_nights            65463 non-null  int64
#  9   adults                          65463 non-null  int64
#  10  children                        65463 non-null  int64
#  11  babies                          65463 non-null  int64
# ...

# %%
df.head()
# Out:
#           hotel  cancellation_status  lead_time  arrival_date_year  \
# 0  Resort Hotel                    0        342               2015
# 1  Resort Hotel                    0        737               2015
# 2  Resort Hotel                    0          7               2015
# 3  Resort Hotel                    0         13               2015
# 4  Resort Hotel                    0         14               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# ...

# %%
drop_cols = [
    'agent',
    'company',
    'reservation_status',
    'reservation_status_date',
    'distribution_channel',
    'arrival_date_week_number',
    'arrival_date_day_of_month',
    'days_in_waiting_list',
    'required_car_parking_spaces'
]

# %%
df.rename(columns={
    'cancellation_status': 'canceled',
    'lead_time': 'lead_days',
    'average_daily_rate': 'adr',
    'market_segment': 'segment',
    'customer_type': 'customer',
    'deposit_type': 'deposit',
    'previous_cancellations': 'prev_cancel',
    'previous_bookings_not_canceled': 'prev_not_cancel',
    'total_of_special_requests': 'special_requests',
    'arrival_date_month': 'month',
    'arrival_date_year': 'year',
    'reserved_room_type': 'reserved_room',
    'assigned_room_type': 'assigned_room',
    'Total Guests': 'total_guests',
    'Total Nights': 'total_nights'
}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65463 entries, 0 to 65462
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   hotel                        65463 non-null  object
#  1   canceled                     65463 non-null  int64
#  2   lead_days                    65463 non-null  int64
#  3   year                         65463 non-null  int64
#  4   month                        65463 non-null  object
#  5   arrival_date_week_number     65463 non-null  int64
#  6   arrival_date_day_of_month    65463 non-null  int64
#  7   stays_in_weekend_nights      65463 non-null  int64
#  8   stays_in_week_nights         65463 non-null  int64
#  9   adults                       65463 non-null  int64
#  10  children                     65463 non-null  int64
#  11  babies                       65463 non-null  int64
#  12  meal                         65463 non-null  object
# ...

# %%
df.drop([
    'agent',
    'company',
    'reservation_status',
    'reservation_status_date',
    'distribution_channel',
    'arrival_date_week_number',
    'arrival_date_day_of_month',
    'days_in_waiting_list',
    'required_car_parking_spaces'
], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65463 entries, 0 to 65462
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   hotel                    65463 non-null  object
#  1   canceled                 65463 non-null  int64
#  2   lead_days                65463 non-null  int64
#  3   year                     65463 non-null  int64
#  4   month                    65463 non-null  object
#  5   stays_in_weekend_nights  65463 non-null  int64
#  6   stays_in_week_nights     65463 non-null  int64
#  7   adults                   65463 non-null  int64
#  8   children                 65463 non-null  int64
#  9   babies                   65463 non-null  int64
#  10  meal                     65463 non-null  object
#  11  country                  65463 non-null  object
#  12  segment                  65463 non-null  object
#  13  is_repeated_guest        65463 non-null  int64
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.show()

# %%
plt.show()

# %%
sns.countplot(x='canceled', data=df)
plt.show()

# %%
sns.boxplot(x='canceled', y='adr', data=df)
plt.show()

# %%
sns.boxplot(x='canceled', y='lead_days', data=df)
plt.show()

# %%
sns.countplot(x='customer', hue='canceled', data=df)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# %%
from sklearn.model_selection import train_test_split

X = df[['lead_days', 'adr', 'total_stay']]
y = df['canceled']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_pred)
# Out:
# 0.6598946001680287

# %%
df.to_csv("cleaned_hotel_data.csv", index=False)

# %%
df.to_csv("cleaned_hotel_data.csv", index=False)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\puspa'

# %%
df.to_csv("cleaned_hotel_data.csv", index=False)

# %%
df.head()
# Out:
#           hotel  canceled  lead_days  year month  stays_in_weekend_nights  \
# 0  Resort Hotel         0        342  2015  July                        0
# 1  Resort Hotel         0        737  2015  July                        0
# 2  Resort Hotel         0          7  2015  July                        0
# 3  Resort Hotel         0         13  2015  July                        0
# 4  Resort Hotel         0         14  2015  July                        0
#
#    stays_in_week_nights  adults  children  babies  ... reserved_room  \
# 0                     0       2         0       0  ...             C
# 1                     0       2         0       0  ...             C
# 2                     1       1         0       0  ...             A
# 3                     1       1         0       0  ...             A
# 4                     2       2         0       0  ...             A
#
#   assigned_room booking_changes     deposit   customer   adr special_requests  \
# ...

# %%
df.to_csv("cleaned_hotel_data.csv", index=False)

# %%
import os
os.listdir()
# Out:
# ['.anaconda',
#  '.bash_history',
#  '.codeium',
#  '.conda',
#  '.config',
#  '.continuum',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.lesshst',
#  '.mamba',
#  '.matplotlib',
#  '.python_history',
#  '.vscode',
#  '.windsurf',
#  'anaconda3',
#  'AppData',
#  'Application Data',
#  'Class 1.ipynb',
#  'class 2.ipynb',
#  'Class 3.ipynb',
#  'cleaned_hotel_data.csv',
#  'Contacts',
#  'Cookies',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Home prtc.ipynb',
#  'Interview prtc.ipynb',
#  'Links',
#  'Local Settings',
#  'Microsoft',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{c6a5a623-2ce2-11f0-b572-d7b4eaf3717d}.TM.blf',
#  'NTUSER.DAT{c6a5a623-2ce2-11f0-b572-d7b4eaf3717d}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{c6a5a623-2ce2-11f0-b572-d7b4eaf3717d}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'PrintHood',
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\puspa'

# %%
import os
os.listdir()
# Out:
# ['.anaconda',
#  '.bash_history',
#  '.codeium',
#  '.conda',
#  '.config',
#  '.continuum',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.lesshst',
#  '.mamba',
#  '.matplotlib',
#  '.python_history',
#  '.vscode',
#  '.windsurf',
#  'anaconda3',
#  'AppData',
#  'Application Data',
#  'Class 1.ipynb',
#  'class 2.ipynb',
#  'Class 3.ipynb',
#  'cleaned_hotel_data.csv',
#  'Contacts',
#  'Cookies',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Home prtc.ipynb',
#  'Interview prtc.ipynb',
#  'Links',
#  'Local Settings',
#  'Microsoft',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{c6a5a623-2ce2-11f0-b572-d7b4eaf3717d}.TM.blf',
#  'NTUSER.DAT{c6a5a623-2ce2-11f0-b572-d7b4eaf3717d}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{c6a5a623-2ce2-11f0-b572-d7b4eaf3717d}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'PrintHood',
# ...

# %%
month_map = {
    'January':1, 'February':2, 'March':3, 'April':4,
    'May':5, 'June':6, 'July':7, 'August':8,
    'September':9, 'October':10, 'November':11, 'December':12
}

df['month_number'] = df['month'].map(month_map)

# %%
df.to_csv("cleaned_hotel_data.csv", index=False)

# %%
import os
os.listdir()
# Out:
# ['.anaconda',
#  '.bash_history',
#  '.codeium',
#  '.conda',
#  '.config',
#  '.continuum',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.lesshst',
#  '.mamba',
#  '.matplotlib',
#  '.python_history',
#  '.vscode',
#  '.windsurf',
#  'anaconda3',
#  'AppData',
#  'Application Data',
#  'Class 1.ipynb',
#  'class 2.ipynb',
#  'Class 3.ipynb',
#  'cleaned_hotel_data.csv',
#  'Contacts',
#  'Cookies',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Home prtc.ipynb',
#  'Interview prtc.ipynb',
#  'Links',
#  'Local Settings',
#  'Microsoft',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{c6a5a623-2ce2-11f0-b572-d7b4eaf3717d}.TM.blf',
#  'NTUSER.DAT{c6a5a623-2ce2-11f0-b572-d7b4eaf3717d}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{c6a5a623-2ce2-11f0-b572-d7b4eaf3717d}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'PrintHood',
# ...

# %%
df.to_csv("cleaned_hotel_data.csv", index=False)
